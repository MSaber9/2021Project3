# %% [markdown]
# <a href="https://colab.research.google.com/github/MSaber9/2021Project3/blob/main/05_dl_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.39.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (56.1.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)

# %%
pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.19.5)
# Requirement already satisfied: networkx==2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx==2.2->hyperopt) (4.4.2)

# %%
pip install "hyperopt==0.2.3"
# Out:
# Requirement already satisfied: hyperopt==0.2.3 in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: networkx==2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (0.16.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.3) (1.3.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx==2.2->hyperopt==0.2.3) (4.4.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import gc
import shap
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers, metrics
from collections import Counter
from hyperopt import fmin, hp, tpe, atpe, Trials, STATUS_OK
from hyperopt.plotting import main_plot_history, main_plot_vars
import uuid

K = keras.backend

rand_state = 42
tf.random.set_seed(rand_state)
np.random.seed(rand_state)

#enable_gpu_memory_growth()

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Newi/2021Project3/
# Out:
# /content/drive/My Drive/Colab Notebooks/Newi/2021Project3

# %%
# !ls
# Out:
# 01_data_cleanup.ipynb	       Data		    models4
# 02_data_analysis.ipynb	       Dataupdate	    models5
# 03_ml_classifier.ipynb	       dl-classifier.ipynb  processed
# 04_dl_anomaly_detection.ipynb  mlids		    tmp

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/Newi/2021Project3/mlids'
# Out:
# conf.py      keras   model_selection.py  tf_utils.py  utils.py
# data	     libs    prediction.py	 transform    visualization.py
# __init__.py  models  __pycache__	 utils2.py

# %%
from mlids.data.dataset import load_dataset
from mlids.data.metadata import FEATURES_NO_VARIANCE
from mlids.visualization import plot_hist, print_binary_performance, plot_pr_curve
from mlids.keras.metrics import AveragePrecisionScoreMetric
from mlids.keras.evaluation import evaluate_model
from mlids.keras.prediction import predict, predict_proba
from mlids.tf_utils import enable_gpu_memory_growth

# %%
from mlids.utils2 import transform_data
# Out:
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
# The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.

# %% [markdown]
# ## 2. Dataset Preparation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Newi/2021Project3/Dataupdate
# Out:
# /content/drive/My Drive/Colab Notebooks/Newi/2021Project3/Dataupdate

# %%
# !ls
# Out:
# bot_02-03-2018.csv
# bruteforce-ftp-ssh_14-02-2018.csv
# bruteforce-web-xss_sql-injection_22-02-2018.csv
# bruteforce-web-xss_sql-injection_23-02-2018.csv
# ddos-loic-http-loic-udp_20-02-2018.csv
# ddos-loic-udp_hoic_21-02-2018.csv
# dos-goldeneye-slowloris_15-02-2018.csv
# dos-slowhttp-hulk_16-02-2018.csv
# infiltration_01-03-2018.csv
# infiltration_28-02-2018.csv
# models

# %%
dataset_base_path = '/content/drive/My Drive/Colab Notebooks/Newi/2021Project3/Dataupdate'

# %% [markdown]
# ### 2.1 Data Loading & Preparation
#
# * training set,
# * validation set and
# * test set.

# %%
dataset = load_dataset(dataset_base_path,
                       omit_cols=FEATURES_NO_VARIANCE + ['timestamp', 'dst_port', 'protocol'],
                       preserve_neg_value_cols=['init_fwd_win_byts', 'init_bwd_win_byts'])

X_train, y_train, X_val, y_val, X_test, y_test, column_names = transform_data(dataset=dataset,
                                                                              imputer_strategy='median',
                                                                              scaler=StandardScaler,
                                                                              attack_samples=100000,
                                                                              random_state=rand_state)

del dataset
# Out:
# Samples:
# ========
# Training: (12986354, 68)
# Val:      (1623294, 68)
# Test:     (1623295, 68)
#
# Training labels:
# ================
# Benign                      10787766
# DDOS attack-HOIC              548809
# DDoS attacks-LOIC-HTTP        460953
# DoS attacks-Hulk              369530
# Bot                           228953
# FTP-BruteForce                154688
# SSH-Bruteforce                150071
# Infilteration                 129547
# DoS attacks-SlowHTTPTest      111912
# DoS attacks-GoldenEye          33206
# DoS attacks-Slowloris           8792
# DDOS attack-LOIC-UDP            1384
# Brute Force -Web                 489
# Brute Force -XSS                 184
# SQL Injection                     70
# Name: label, dtype: int64
#
# Validation labels:
# ==================
# Benign                      1348471
# DDOS attack-HOIC              68601
# DDoS attacks-LOIC-HTTP        57619
# DoS attacks-Hulk              46191
# Bot                           28619
# FTP-BruteForce                19336
# SSH-Bruteforce                18759
# Infilteration                 16193
# DoS attacks-SlowHTTPTest      13989
# DoS attacks-GoldenEye          4151
# DoS attacks-Slowloris          1099
# DDOS attack-LOIC-UDP            173
# Brute Force -Web                 61
# Brute Force -XSS                 23
# SQL Injection                     9
# Name: label, dtype: int64
#
# Test labels:
# ============
# Benign                      1348471
# DDOS attack-HOIC              68602
# DDoS attacks-LOIC-HTTP        57619
# DoS attacks-Hulk              46191
# Bot                           28619
# FTP-BruteForce                19336
# SSH-Bruteforce                18759
# Infilteration                 16194
# DoS attacks-SlowHTTPTest      13989
# DoS attacks-GoldenEye          4151
# DoS attacks-Slowloris          1099
# DDOS attack-LOIC-UDP            173
# Brute Force -Web                 61
# Brute Force -XSS                 23
# SQL Injection                     8
# Name: label, dtype: int64
# Samples:
# ========
# Training: (12986354, 68)
# Val:      (1623294, 68)
# Test:     (1623295, 68)
#
# Missing values:
# ===============
# Training: 0
# Val:      0
# Test:     0
#
# Scaling:
# ========
# Training: min=-2.3386325146596727, max=3405.803358093496
# Val:      min=-2.3386325146596727, max=807.4353509687579
# Test:     min=-2.3386325146596727, max=2812.3493309079604
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# Samples:
# ========
# Training: (13542229, 68)
#
# Training labels:
# ================
# Counter({0: 10787766, 8: 548809, 10: 460953, 5: 369530, 1: 228953, 11: 154688, 14: 150071, 12: 129547, 6: 111912, 2: 100000, 4: 100000, 7: 100000, 9: 100000, 13: 100000, 3: 100000})

# %% [markdown]
# ### 2.2 Target Grouping & Class Weight Calculation
#
# In this step we create the binary target variable by grouping all malicious network traffic into a single attack category represented by the positive class `1`, whereas benign traffic is represented as the negative class `0`.
#
# Furthermore, we calculate the weights for each class, given by the proportion of samples of this class in the training set.
# For the majority class, the class weight is `1`.
# For the minority class, the class weight is calculated with the following formula:
# \begin{align}
# \frac{(sum\_majority\_class)}{(sum\_minority\_class)} \\
# \end{align}
# In our case this translates to:
# \begin{align}
# \frac{(sum\_negative\_class)}{(sum\_positive\_class)} \\
# \end{align}

# %%
y_train_is_attack = (y_train != 0).astype('int')

minority_class_weight = len(y_train_is_attack[y_train_is_attack == 0]) / len(y_train_is_attack[y_train_is_attack == 1])

class_weights = { 
    0: 1, 
    1: minority_class_weight
}

# %% [markdown]
# ## 3. Static Model Training
#
# In this section, we train a static model, comprised of `3` layers, each containing `400` units, using the `Adam` optimizer.
# We execute two training runs. In run one we ignore the class imbalance, whereas in run two we use the class weights to take the class imblance into account.
# Afterwards we compare the results and select one approach to use for hyperparameter optimization.

# %%
def create_model(input_dims, 
                 nr_layers, 
                 nr_units, 
                 activation, 
                 kerner_initializer,
                 optimizer,
                 dropout_layer=None):
    model = models.Sequential()
    model.add(layers.Input(shape=[input_dims]))
    
    for l in range(nr_layers):
        model.add(layers.Dense(nr_units, activation=activation, kernel_initializer=kerner_initializer))
        
    if dropout_layer:
        model.add(dropout_layer)
    
    model.add(layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=optimizer, 
                  loss='binary_crossentropy', 
                  metrics=[metrics.AUC(curve='PR'),
                           metrics.Precision(), 
                           metrics.Recall()])
    return model

# %%
def train_static_model(X_train, y_train, X_val, y_val, model_path, class_weights=None):    
    input_dims = X_train.shape[1]
    epochs = 20
    batch_size = 4096
    
    K.clear_session()
    gc.collect()

    model = create_model(input_dims=input_dims,
                         nr_layers=3,
                         nr_units=400,
                         activation='selu',
                         kerner_initializer='lecun_normal',
                         optimizer=optimizers.Adam())

    print(model.summary())
    
    mc = callbacks.ModelCheckpoint(filepath=model_path, save_best_only=True)

    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=3)

    hist = model.fit(x=X_train, 
                     y=y_train,
                     validation_data=(X_val, y_val),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[
                         lr_scheduler,
                         mc
                     ])
    
    return model, hist

# %% [markdown]
# ### 3.1 Static Model without class weights
#
# In this step, we train the static model withouth using class weights.

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Newi/2021Project3/
# Out:
# /content/drive/My Drive/Colab Notebooks/Newi/2021Project3

# %%
# !ls
# Out:
# 01_data_cleanup.ipynb	       Data		    models4
# 02_data_analysis.ipynb	       Dataupdate	    models5
# 03_ml_classifier.ipynb	       dl-classifier.ipynb  processed
# 04_dl_anomaly_detection.ipynb  mlids		    tmp

# %%
model_no_class_weights, hist = train_static_model(X_train, 
                                                  y_train_is_attack, 
                                                  X_val, 
                                                  y_val.label_is_attack.values,
                                                  'models5/model_no_class_weights.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 400)               27600
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 348,801
# Trainable params: 348,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 3307/3307 [==============================] - 95s 28ms/step - loss: 0.1014 - auc: 0.9592 - precision: 0.9476 - recall: 0.9025 - val_loss: 0.0594 - val_auc: 0.9717 - val_precision: 0.9846 - val_recall: 0.9360
# Epoch 2/20
# 3307/3307 [==============================] - 85s 26ms/step - loss: 0.0623 - auc: 0.9778 - precision: 0.9828 - recall: 0.9434 - val_loss: 0.0577 - val_auc: 0.9714 - val_precision: 0.9854 - val_recall: 0.9354
# Epoch 3/20
# 3307/3307 [==============================] - 84s 25ms/step - loss: 0.0585 - auc: 0.9790 - precision: 0.9857 - recall: 0.9456 - val_loss: 0.0662 - val_auc: 0.9710 - val_precision: 0.9539 - val_recall: 0.9468
# Epoch 4/20
# 3307/3307 [==============================] - 85s 26ms/step - loss: 0.0601 - auc: 0.9788 - precision: 0.9846 - recall: 0.9434 - val_loss: 0.0588 - val_auc: 0.9725 - val_precision: 0.9810 - val_recall: 0.9361
# Epoch 5/20
# 3307/3307 [==============================] - 84s 26ms/step - loss: 0.0599 - auc: 0.9791 - precision: 0.9845 - recall: 0.9426 - val_loss: 0.0565 - val_auc: 0.9734 - val_precision: 0.9757 - val_recall: 0.9425
# Epoch 6/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.0592 - auc: 0.9793 - precision: 0.9847 - recall: 0.9424 - val_loss: 0.0560 - val_auc: 0.9733 - val_precision: 0.9826 - val_recall: 0.9358
# Epoch 7/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.0582 - auc: 0.9797 - precision: 0.9848 - recall: 0.9429 - val_loss: 0.0523 - val_auc: 0.9738 - val_precision: 0.9870 - val_recall: 0.9373
# Epoch 8/20
# 3307/3307 [==============================] - 85s 26ms/step - loss: 0.0561 - auc: 0.9801 - precision: 0.9866 - recall: 0.9440 - val_loss: 0.0539 - val_auc: 0.9745 - val_precision: 0.9849 - val_recall: 0.9355
# Epoch 9/20
# 3307/3307 [==============================] - 93s 28ms/step - loss: 0.0579 - auc: 0.9798 - precision: 0.9859 - recall: 0.9428 - val_loss: 0.0539 - val_auc: 0.9737 - val_precision: 0.9840 - val_recall: 0.9361
# Epoch 10/20
# 3307/3307 [==============================] - 86s 26ms/step - loss: 0.0544 - auc: 0.9806 - precision: 0.9889 - recall: 0.9455 - val_loss: 0.0525 - val_auc: 0.9745 - val_precision: 0.9888 - val_recall: 0.9367
# Epoch 11/20
# 3307/3307 [==============================] - 85s 26ms/step - loss: 0.0501 - auc: 0.9817 - precision: 0.9938 - recall: 0.9473 - val_loss: 0.0497 - val_auc: 0.9754 - val_precision: 0.9909 - val_recall: 0.9398
# Epoch 12/20
# 3307/3307 [==============================] - 89s 27ms/step - loss: 0.0527 - auc: 0.9815 - precision: 0.9894 - recall: 0.9455 - val_loss: 0.0497 - val_auc: 0.9762 - val_precision: 0.9928 - val_recall: 0.9359
# Epoch 13/20
# 3307/3307 [==============================] - 86s 26ms/step - loss: 0.0490 - auc: 0.9822 - precision: 0.9931 - recall: 0.9494 - val_loss: 0.0494 - val_auc: 0.9757 - val_precision: 0.9904 - val_recall: 0.9390
# Epoch 14/20
# 3307/3307 [==============================] - 87s 26ms/step - loss: 0.0489 - auc: 0.9823 - precision: 0.9930 - recall: 0.9496 - val_loss: 0.0492 - val_auc: 0.9759 - val_precision: 0.9934 - val_recall: 0.9358
# Epoch 15/20
# 3307/3307 [==============================] - 86s 26ms/step - loss: 0.0507 - auc: 0.9820 - precision: 0.9911 - recall: 0.9472 - val_loss: 0.0494 - val_auc: 0.9759 - val_precision: 0.9840 - val_recall: 0.9438
# Epoch 16/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.0496 - auc: 0.9822 - precision: 0.9924 - recall: 0.9485 - val_loss: 0.0492 - val_auc: 0.9765 - val_precision: 0.9924 - val_recall: 0.9386
# Epoch 17/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.0486 - auc: 0.9825 - precision: 0.9932 - recall: 0.9497 - val_loss: 0.0493 - val_auc: 0.9758 - val_precision: 0.9894 - val_recall: 0.9406
# Epoch 18/20
# 3307/3307 [==============================] - 81s 24ms/step - loss: 0.0480 - auc: 0.9828 - precision: 0.9935 - recall: 0.9501 - val_loss: 0.0486 - val_auc: 0.9768 - val_precision: 0.9918 - val_recall: 0.9393
# Epoch 19/20
# 3307/3307 [==============================] - 81s 25ms/step - loss: 0.0482 - auc: 0.9827 - precision: 0.9934 - recall: 0.9500 - val_loss: 0.0486 - val_auc: 0.9764 - val_precision: 0.9915 - val_recall: 0.9395
# Epoch 20/20
# 3307/3307 [==============================] - 81s 25ms/step - loss: 0.0480 - auc: 0.9828 - precision: 0.9933 - recall: 0.9503 - val_loss: 0.0486 - val_auc: 0.9764 - val_precision: 0.9908 - val_recall: 0.9403

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the metrics and learning curves, we observe that the model does not overfit the training set.

# %%
model_no_class_weights = models.load_model('models5/model_no_class_weights.h5')
evaluate_model(model_no_class_weights, 
               X_train, 
               y_train_is_attack,
               X_val, y_val.label_is_attack.values, 
               metric_title='Loss / PR AUC / Precision / Recall')
# Out:
# Evaluation:
# ===========
#        Loss / PR AUC / Precision / Recall
# Train: [0.0479755625128746, 0.9826938509941101, 0.9929189085960388, 0.9507842659950256]
# Val:   [0.04859758913516998, 0.9763872027397156, 0.9908058643341064, 0.9403179287910461]

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# The performance of the model is quite compelling with a PR score of `0.97718`.
# Looking at the classification report we notice that the precision of the positive class is quite high (`0.992`), while having a lower recall (`0.939`). This effect is most likely caused by the overwhelming amount of samples from the negative class in the training set.
# Consequently, the confusion matrix reveals a low amount of false-positives (`1956` samples) but a high amount of false-negatives (`16898` samples).
# The misclassification statistic shows that the majority of false-negative results originate from the attack category of `Infiltration`, with a misclassification rate of `98%`.

# %%
pred_val_score = predict_proba(model_no_class_weights, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9773215504776477

# %%
pred_val = predict(model_no_class_weights, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.988     0.998     0.993   1348471
#            1      0.991     0.940     0.965    274823
#
#     accuracy                          0.988   1623294
#    macro avg      0.989     0.969     0.979   1623294
# weighted avg      0.988     0.988     0.988   1623294
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                         misclassified    total  percent_misclassified
# Infilteration                   15734    16193               0.971654
# SQL Injection                       1        9               0.111111
# Brute Force -Web                    3       61               0.049180
# Brute Force -XSS                    1       23               0.043478
# Bot                               563    28619               0.019672
# DoS attacks-Slowloris               6     1099               0.005460
# Benign                           2398  1348471               0.001778
# DDoS attacks-LOIC-HTTP             77    57619               0.001336
# DDOS attack-HOIC                   15    68601               0.000219
# SSH-Bruteforce                      2    18759               0.000107

# %% [markdown]
# ### 3.2 Static Model using class weights
#
# In this step, we train the static model using class weights to take the class imbalance into account.

# %%
model_class_weights, hist = train_static_model(X_train, 
                                               y_train_is_attack, 
                                               X_val, 
                                               y_val.label_is_attack.values,
                                               'models5/model_class_weight.h5',
                                               class_weights)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 400)               27600
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 348,801
# Trainable params: 348,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 3307/3307 [==============================] - 85s 25ms/step - loss: 0.2319 - auc: 0.9570 - precision: 0.8853 - recall: 0.9445 - val_loss: 0.0811 - val_auc: 0.9715 - val_precision: 0.9576 - val_recall: 0.9475
# Epoch 2/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1605 - auc: 0.9774 - precision: 0.9555 - recall: 0.9545 - val_loss: 0.0750 - val_auc: 0.9709 - val_precision: 0.9597 - val_recall: 0.9472
# Epoch 3/20
# 3307/3307 [==============================] - 86s 26ms/step - loss: 0.1541 - auc: 0.9784 - precision: 0.9626 - recall: 0.9547 - val_loss: 0.0790 - val_auc: 0.9715 - val_precision: 0.9495 - val_recall: 0.9486
# Epoch 4/20
# 3307/3307 [==============================] - 85s 26ms/step - loss: 0.1521 - auc: 0.9787 - precision: 0.9635 - recall: 0.9550 - val_loss: 0.0844 - val_auc: 0.9678 - val_precision: 0.9356 - val_recall: 0.9479
# Epoch 5/20
# 3307/3307 [==============================] - 84s 25ms/step - loss: 0.1456 - auc: 0.9795 - precision: 0.9643 - recall: 0.9572 - val_loss: 0.0778 - val_auc: 0.9730 - val_precision: 0.9425 - val_recall: 0.9531
# Epoch 6/20
# 3307/3307 [==============================] - 84s 25ms/step - loss: 0.1359 - auc: 0.9813 - precision: 0.9688 - recall: 0.9609 - val_loss: 0.0686 - val_auc: 0.9755 - val_precision: 0.9634 - val_recall: 0.9537
# Epoch 7/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1339 - auc: 0.9817 - precision: 0.9706 - recall: 0.9611 - val_loss: 0.0650 - val_auc: 0.9756 - val_precision: 0.9642 - val_recall: 0.9535
# Epoch 8/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.1332 - auc: 0.9818 - precision: 0.9711 - recall: 0.9612 - val_loss: 0.0634 - val_auc: 0.9758 - val_precision: 0.9657 - val_recall: 0.9531
# Epoch 9/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.1323 - auc: 0.9821 - precision: 0.9713 - recall: 0.9614 - val_loss: 0.0664 - val_auc: 0.9760 - val_precision: 0.9652 - val_recall: 0.9536
# Epoch 10/20
# 3307/3307 [==============================] - 81s 25ms/step - loss: 0.1325 - auc: 0.9821 - precision: 0.9715 - recall: 0.9612 - val_loss: 0.0664 - val_auc: 0.9762 - val_precision: 0.9643 - val_recall: 0.9540
# Epoch 11/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1332 - auc: 0.9820 - precision: 0.9715 - recall: 0.9608 - val_loss: 0.0601 - val_auc: 0.9759 - val_precision: 0.9655 - val_recall: 0.9537
# Epoch 12/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.1324 - auc: 0.9822 - precision: 0.9720 - recall: 0.9610 - val_loss: 0.0645 - val_auc: 0.9758 - val_precision: 0.9650 - val_recall: 0.9536
# Epoch 13/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.1318 - auc: 0.9822 - precision: 0.9718 - recall: 0.9613 - val_loss: 0.0621 - val_auc: 0.9760 - val_precision: 0.9640 - val_recall: 0.9538
# Epoch 14/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1316 - auc: 0.9823 - precision: 0.9720 - recall: 0.9613 - val_loss: 0.0657 - val_auc: 0.9763 - val_precision: 0.9656 - val_recall: 0.9537
# Epoch 15/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1301 - auc: 0.9827 - precision: 0.9728 - recall: 0.9614 - val_loss: 0.0636 - val_auc: 0.9765 - val_precision: 0.9657 - val_recall: 0.9538
# Epoch 16/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1300 - auc: 0.9828 - precision: 0.9728 - recall: 0.9614 - val_loss: 0.0642 - val_auc: 0.9766 - val_precision: 0.9660 - val_recall: 0.9538
# Epoch 17/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1293 - auc: 0.9829 - precision: 0.9728 - recall: 0.9616 - val_loss: 0.0632 - val_auc: 0.9764 - val_precision: 0.9655 - val_recall: 0.9539
# Epoch 18/20
# 3307/3307 [==============================] - 81s 25ms/step - loss: 0.1291 - auc: 0.9830 - precision: 0.9730 - recall: 0.9616 - val_loss: 0.0626 - val_auc: 0.9767 - val_precision: 0.9662 - val_recall: 0.9538
# Epoch 19/20
# 3307/3307 [==============================] - 82s 25ms/step - loss: 0.1298 - auc: 0.9828 - precision: 0.9731 - recall: 0.9613 - val_loss: 0.0638 - val_auc: 0.9767 - val_precision: 0.9663 - val_recall: 0.9538
# Epoch 20/20
# 3307/3307 [==============================] - 83s 25ms/step - loss: 0.1292 - auc: 0.9830 - precision: 0.9732 - recall: 0.9616 - val_loss: 0.0640 - val_auc: 0.9767 - val_precision: 0.9661 - val_recall: 0.9539

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the metrics and learning curves, we observe that the model does not significantly overfit the training set.

# %%
model_class_weights = models.load_model('models5/model_class_weight.h5')
evaluate_model(model_class_weights, 
               X_train, 
               y_train_is_attack, 
               X_val, 
               y_val.label_is_attack.values,
               metric_title='Loss / PR AUC / Precision / Recall')
# Out:
# Evaluation:
# ===========
#        Loss / PR AUC / Precision / Recall
# Train: [0.058524906635284424, 0.9822824001312256, 0.9723786115646362, 0.9613340497016907]
# Val:   [0.060103461146354675, 0.9758756160736084, 0.9654701352119446, 0.9537084102630615]

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# The performance of the model in terms of the PR score is only marginally better than the previous model with a score of `0.97735`.
# However, the classification report shows a different combination of precision and recall for the positive class, with a precision of `0.965` and recall of `0.954`.
# The confusion matrix reveals a nearly equal amount of false-positives (`9375` samples) and false-negatives (`12649` samples).
# Even though the misclassification rate of `Infiltration` was reduced to `77%`, it still is very high.

# %%
pred_val_score = predict_proba(model_class_weights, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9767262789756911

# %%
pred_val = predict(model_class_weights, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.991     0.993     0.992   1348471
#            1      0.965     0.954     0.960    274823
#
#     accuracy                          0.986   1623294
#    macro avg      0.978     0.973     0.976   1623294
# weighted avg      0.986     0.986     0.986   1623294
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                         misclassified    total  percent_misclassified
# Infilteration                   12592    16193               0.777620
# SQL Injection                       1        9               0.111111
# Brute Force -Web                    3       61               0.049180
# Brute Force -XSS                    1       23               0.043478
# Benign                           9374  1348471               0.006952
# DoS attacks-Slowloris               6     1099               0.005460
# Bot                                54    28619               0.001887
# DDoS attacks-LOIC-HTTP             60    57619               0.001041
# SSH-Bruteforce                      2    18759               0.000107
# DDOS attack-HOIC                    3    68601               0.000044

# %% [markdown]
# ### 3.3 Model Comparison
#
# |Model|PR Score|Precision Positive|Recall Positive|False-Positives|False-Negatives|
# |---|---|---|---|---|---|
# |No class-weights|0.97718|0.992|**0.939**|1956|**16898**|
# |Class-weights|0.97735|0.965|**0.954**|9375|**12649**|
#
# Using the class weights during training, we obtain a reduction in precision of `~2.7%` but an increase in recall of `~1.6%`.
# Consequently, the number of false-negatives are reduced, while the number of false-positives are increased by an acceptable amount.
# As the primary goal of our classifier is to detect as many attacks as possible, we choose to continue using the second approach, applying the class weights during training.
#
# Both models suffer from a high misclassification rate in regards to the attack category of `Infiltration`, most likely due to the fact that benign traffic and infiltration traffic is very similar.

# %% [markdown]
# ## 4. Model Training with Hyperparameter Optimization
#
# In this section we will use the [Hyperopt](https://github.com/hyperopt/hyperopt) library to train and evaluate various model architectures in combination with different hyperparameter configurations. For this purpose, we define a training method that accepts the model parameters from the Hyperopt library, dynamically creating the model, performing training and returning the lowest validation loss.

# %%
def train_dynamic_model(args):
    print('\nRun') 
    print('==========')
    print('Parameters:\n{}'.format(args))
    
    epochs = int(args['epochs'])
    batch_size = int(args['batch_size'])
    nr_layers = int(args['nr_layers'])
    nr_units = int(args['nr_units'])
    activation = args['activation']
    dropout_rate = args['dropout_rate']
    model_name = 'models5/{}.h5'.format(uuid.uuid4())
    
    if activation == 'elu':
        kerner_initializer = 'he_normal'
        dropout_layer = layers.Dropout(dropout_rate)
    elif activation == 'selu':
        kerner_initializer = 'lecun_normal'
        dropout_layer = layers.AlphaDropout(dropout_rate)
    else:
        raise ValueError('Invalid activation "{}" supplied.'.format(opt_args['name']))
    
    opt_name = args['optimizer']['name']
    opt_lr_mult = args['optimizer']['lr_mult']
    
    if opt_name == 'sgd':
        optimizer = optimizers.SGD(lr=(0.01 * opt_lr_mult), momentum=0.9, nesterov=True)
    elif opt_name == 'adam':
        optimizer = optimizers.Adam(lr=(0.001 * opt_lr_mult))
    elif opt_name == 'nadam':
        optimizer = optimizers.Nadam(lr=(0.002 * opt_lr_mult))
    else:
        raise ValueError('Invalid optimizer "{}" supplied.'.format(opt_args['name']))
        
    K.clear_session()
    gc.collect()
    
    model = create_model(input_dims=X_train.shape[1], 
                         nr_layers=nr_layers, 
                         nr_units=nr_units, 
                         activation=activation, 
                         kerner_initializer=kerner_initializer,
                         optimizer=optimizer,
                         dropout_layer=dropout_layer)
    
    mc = callbacks.ModelCheckpoint(filepath=model_name, save_best_only=True, verbose=0)
    
    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=5)
    
    hist = model.fit(x=X_train, 
                     y=y_train_is_attack, 
                     validation_data=(X_val, y_val.label_is_attack.values),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[
                         lr_scheduler,
                         mc
                     ],
                     verbose=2)
    
    best_loss = np.amin(hist.history['val_loss']) 
    print('Best loss: {}'.format(best_loss))
    print('Model: {}'.format(model_name))
    
    return {
        'loss': best_loss,
        'status': STATUS_OK,
        'model_name': model_name
    }

# %% [markdown]
# ### 4.1 Search-Space Definition and Training
#
# In order to try a variety of different model architectures and hyperparameters, we have to define the search spaces for each of our parameters. These search spaces will be used to choose values for the corresponding parameters.
# The following search spaces are utilized:
# * Number of layers: uniform integer space in the interval of `[2, 6]`.
# * Number of units: uniform integer space in the interval of `[100, 1000]` with step size `100`.
# * Activation function: choice of `elu` and `selu` activation functions.
# * Dropout rate: uniform space in the interval of `[0, 0.5]`.
# * Optimizer: choice of `SGD`, `Adam` or `Nadam`.
# * Learning rate multiplier: log-uniform space in the interval of `[-0.5, 1]`. This value is used to multiply the default learning rate of the chosen optimizer.
#
# Training is performed on `50` models, with `30` epochs per model and a rather large batch-size of `4096`, which is chosen to keep the training time per model reasonable.
#
# We use the [Tree of Parzen Estimators (TPE)](https://papers.nips.cc/paper/4443-algorithms-for-hyper-parameter-optimization.pdf) search algorithm, provided by Hyperopt, to optimize the search process.

# %%
trials = Trials()

space = { 
    'epochs': hp.choice('epochs', [30]),  
    'batch_size': hp.choice('batch_size', [4096]),
    'nr_layers': hp.quniform('nr_layers', 2, 6, 1),  
    'nr_units': hp.quniform('nr_units', 100, 1000, 100), 
    'activation': hp.choice('activation', ['elu', 'selu']),
    'dropout_rate': hp.uniform('dropout_rate', 0, 0.5),
    'optimizer': hp.choice('optimizer', [
        {
            'name': 'sgd',
            'lr_mult': hp.loguniform('sgd_lr_rate_mult', -0.5, 1),
        }, 
        {
            'name': 'adam',
            'lr_mult': hp.loguniform('adam_lr_rate_mult', -0.5, 1),
        },
        {
            'name': 'nadam',
            'lr_mult': hp.loguniform('nadam_lr_rate_mult', -0.5, 1),
        }
    ])
}


best_run = fmin(fn=train_dynamic_model,
                space=space,
                algo=tpe.suggest,
                max_evals=50,
                trials=trials)
# Out:
# Run
# ==========
# Parameters:
# {'activation': 'selu', 'batch_size': 4096, 'dropout_rate': 0.3215973444199586, 'epochs': 30, 'nr_layers': 5.0, 'nr_units': 700.0, 'optimizer': {'lr_mult': 2.0694601635985372, 'name': 'adam'}}
# Epoch 1/30
# 3307/3307 - 266s - loss: 0.1916 - auc: 0.9693 - precision: 0.9351 - recall: 0.9480 - val_loss: 0.1773 - val_auc: 0.9055 - val_precision: 0.9484 - val_recall: 0.6899
#
# Epoch 2/30
# 3307/3307 - 261s - loss: 0.1836 - auc: 0.9728 - precision: 0.9455 - recall: 0.9427 - val_loss: 0.0707 - val_auc: 0.9658 - val_precision: 0.9553 - val_recall: 0.9480
#
# Epoch 3/30
# 3307/3307 - 256s - loss: 0.1615 - auc: 0.9759 - precision: 0.9603 - recall: 0.9521 - val_loss: 0.1462 - val_auc: 0.9534 - val_precision: 0.8291 - val_recall: 0.9557
#
# Epoch 4/30
# 3307/3307 - 259s - loss: 0.1599 - auc: 0.9755 - precision: 0.9607 - recall: 0.9528 - val_loss: 0.0813 - val_auc: 0.9626 - val_precision: 0.9566 - val_recall: 0.9370
#
# Epoch 5/30
# 3307/3307 - 263s - loss: 0.1537 - auc: 0.9769 - precision: 0.9618 - recall: 0.9551 - val_loss: 0.0659 - val_auc: 0.9685 - val_precision: 0.9624 - val_recall: 0.9479
#
# Epoch 6/30
# 3307/3307 - 262s - loss: 0.1556 - auc: 0.9763 - precision: 0.9632 - recall: 0.9543 - val_loss: 0.0752 - val_auc: 0.9617 - val_precision: 0.9523 - val_recall: 0.9533
#
# Epoch 7/30
# 3307/3307 - 264s - loss: 0.1536 - auc: 0.9769 - precision: 0.9623 - recall: 0.9552 - val_loss: 0.0748 - val_auc: 0.9649 - val_precision: 0.9625 - val_recall: 0.9494
#
# Epoch 8/30
# 3307/3307 - 261s - loss: 0.1556 - auc: 0.9764 - precision: 0.9625 - recall: 0.9547 - val_loss: 0.0620 - val_auc: 0.9678 - val_precision: 0.9726 - val_recall: 0.9479
#
# Epoch 9/30
# 3307/3307 - 260s - loss: 0.1544 - auc: 0.9765 - precision: 0.9641 - recall: 0.9547 - val_loss: 0.0812 - val_auc: 0.9622 - val_precision: 0.9480 - val_recall: 0.9491
#
# Epoch 10/30
# 3307/3307 - 256s - loss: 0.1561 - auc: 0.9761 - precision: 0.9646 - recall: 0.9542 - val_loss: 0.0701 - val_auc: 0.9647 - val_precision: 0.9605 - val_recall: 0.9489
#
# Epoch 11/30
# 3307/3307 - 255s - loss: 0.1546 - auc: 0.9767 - precision: 0.9659 - recall: 0.9552 - val_loss: 0.0599 - val_auc: 0.9709 - val_precision: 0.9677 - val_recall: 0.9476
#
# Epoch 12/30
# 3307/3307 - 258s - loss: 0.1507 - auc: 0.9770 - precision: 0.9678 - recall: 0.9554 - val_loss: 0.0879 - val_auc: 0.9596 - val_precision: 0.9558 - val_recall: 0.9480
#
# Epoch 13/30
# 3307/3307 - 260s - loss: 0.1600 - auc: 0.9754 - precision: 0.9641 - recall: 0.9535 - val_loss: 0.0910 - val_auc: 0.9521 - val_precision: 0.9560 - val_recall: 0.9476
#
# Epoch 14/30
# 3307/3307 - 263s - loss: 0.1568 - auc: 0.9757 - precision: 0.9702 - recall: 0.9532 - val_loss: 0.0639 - val_auc: 0.9651 - val_precision: 0.9626 - val_recall: 0.9518
#
# Epoch 15/30
# 3307/3307 - 257s - loss: 0.1619 - auc: 0.9746 - precision: 0.9653 - recall: 0.9524 - val_loss: 0.1019 - val_auc: 0.9512 - val_precision: 0.9180 - val_recall: 0.9541
#
# Epoch 16/30
# 3307/3307 - 258s - loss: 0.1508 - auc: 0.9771 - precision: 0.9683 - recall: 0.9551 - val_loss: 0.0683 - val_auc: 0.9659 - val_precision: 0.9716 - val_recall: 0.9479
#
# Epoch 17/30
# 3307/3307 - 256s - loss: 0.1388 - auc: 0.9796 - precision: 0.9758 - recall: 0.9583 - val_loss: 0.0570 - val_auc: 0.9702 - val_precision: 0.9706 - val_recall: 0.9517
#
# Epoch 18/30
# 3307/3307 - 258s - loss: 0.1418 - auc: 0.9792 - precision: 0.9720 - recall: 0.9576 - val_loss: 0.0624 - val_auc: 0.9675 - val_precision: 0.9653 - val_recall: 0.9532
#
# Epoch 19/30
# 3307/3307 - 257s - loss: 0.1369 - auc: 0.9801 - precision: 0.9769 - recall: 0.9586 - val_loss: 0.0599 - val_auc: 0.9678 - val_precision: 0.9677 - val_recall: 0.9525
#
# Epoch 20/30
# 3307/3307 - 270s - loss: 0.1368 - auc: 0.9801 - precision: 0.9769 - recall: 0.9586 - val_loss: 0.0618 - val_auc: 0.9667 - val_precision: 0.9658 - val_recall: 0.9534
#
# Epoch 21/30
# 3307/3307 - 258s - loss: 0.1372 - auc: 0.9800 - precision: 0.9766 - recall: 0.9585 - val_loss: 0.0602 - val_auc: 0.9699 - val_precision: 0.9652 - val_recall: 0.9532
#
# Epoch 22/30
# 3307/3307 - 261s - loss: 0.1375 - auc: 0.9800 - precision: 0.9759 - recall: 0.9585 - val_loss: 0.0615 - val_auc: 0.9685 - val_precision: 0.9652 - val_recall: 0.9534
#
# Epoch 23/30
# 3307/3307 - 257s - loss: 0.1348 - auc: 0.9806 - precision: 0.9773 - recall: 0.9592 - val_loss: 0.0575 - val_auc: 0.9702 - val_precision: 0.9675 - val_recall: 0.9532
#
# Epoch 24/30
# 3307/3307 - 254s - loss: 0.1347 - auc: 0.9807 - precision: 0.9774 - recall: 0.9592 - val_loss: 0.0580 - val_auc: 0.9685 - val_precision: 0.9685 - val_recall: 0.9529
#
# Epoch 25/30
# 3307/3307 - 257s - loss: 0.1346 - auc: 0.9807 - precision: 0.9774 - recall: 0.9592 - val_loss: 0.0584 - val_auc: 0.9706 - val_precision: 0.9674 - val_recall: 0.9533
#
# Epoch 26/30
# 3307/3307 - 253s - loss: 0.1345 - auc: 0.9807 - precision: 0.9774 - recall: 0.9592 - val_loss: 0.0581 - val_auc: 0.9703 - val_precision: 0.9687 - val_recall: 0.9529
#
# Epoch 27/30
# 3307/3307 - 257s - loss: 0.1345 - auc: 0.9807 - precision: 0.9774 - recall: 0.9592 - val_loss: 0.0573 - val_auc: 0.9704 - val_precision: 0.9689 - val_recall: 0.9526
#
# Epoch 28/30
# 3307/3307 - 253s - loss: 0.1341 - auc: 0.9809 - precision: 0.9774 - recall: 0.9594 - val_loss: 0.0573 - val_auc: 0.9704 - val_precision: 0.9688 - val_recall: 0.9530
#
# Epoch 29/30
# 3307/3307 - 252s - loss: 0.1341 - auc: 0.9809 - precision: 0.9775 - recall: 0.9593 - val_loss: 0.0580 - val_auc: 0.9703 - val_precision: 0.9681 - val_recall: 0.9530
#
# Epoch 30/30
# 3307/3307 - 257s - loss: 0.1340 - auc: 0.9809 - precision: 0.9775 - recall: 0.9593 - val_loss: 0.0582 - val_auc: 0.9704 - val_precision: 0.9681 - val_recall: 0.9531
#
# Best loss: 0.05701765790581703
# Model: models5/814e7ecb-4ade-4b25-b1ca-e0a8cf898c3a.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'selu', 'batch_size': 4096, 'dropout_rate': 0.4578714228323914, 'epochs': 30, 'nr_layers': 5.0, 'nr_units': 700.0, 'optimizer': {'lr_mult': 0.6206381135404898, 'name': 'nadam'}}
# Epoch 1/30
# 3307/3307 - 280s - loss: 0.2354 - auc: 0.9603 - precision: 0.8981 - recall: 0.9408 - val_loss: 0.1045 - val_auc: 0.9511 - val_precision: 0.9451 - val_recall: 0.9477
#
# Epoch 2/30
# 3307/3307 - 276s - loss: 0.1827 - auc: 0.9723 - precision: 0.9432 - recall: 0.9471 - val_loss: 0.0821 - val_auc: 0.9610 - val_precision: 0.9691 - val_recall: 0.9414
#
# Epoch 3/30
# 3307/3307 - 283s - loss: 0.1615 - auc: 0.9758 - precision: 0.9608 - recall: 0.9512 - val_loss: 0.1314 - val_auc: 0.9479 - val_precision: 0.8675 - val_recall: 0.9551
#
# Epoch 4/30
# 3307/3307 - 275s - loss: 0.1571 - auc: 0.9764 - precision: 0.9611 - recall: 0.9534 - val_loss: 0.0778 - val_auc: 0.9629 - val_precision: 0.9572 - val_recall: 0.9481
#
# Epoch 5/30
# 3307/3307 - 268s - loss: 0.1531 - auc: 0.9774 - precision: 0.9602 - recall: 0.9552 - val_loss: 0.0747 - val_auc: 0.9655 - val_precision: 0.9591 - val_recall: 0.9530
#
# Epoch 6/30
# 3307/3307 - 266s - loss: 0.1534 - auc: 0.9771 - precision: 0.9590 - recall: 0.9553 - val_loss: 0.0899 - val_auc: 0.9603 - val_precision: 0.9347 - val_recall: 0.9497
#
# Epoch 7/30
# 3307/3307 - 272s - loss: 0.1517 - auc: 0.9774 - precision: 0.9611 - recall: 0.9560 - val_loss: 0.0907 - val_auc: 0.9607 - val_precision: 0.9427 - val_recall: 0.9536
#
# Epoch 8/30
# 3307/3307 - 266s - loss: 0.1494 - auc: 0.9779 - precision: 0.9631 - recall: 0.9572 - val_loss: 0.0749 - val_auc: 0.9640 - val_precision: 0.9548 - val_recall: 0.9521
#
# Epoch 9/30
# 3307/3307 - 269s - loss: 0.1476 - auc: 0.9784 - precision: 0.9631 - recall: 0.9574 - val_loss: 0.0852 - val_auc: 0.9607 - val_precision: 0.9559 - val_recall: 0.9505
#
# Epoch 10/30
# 3307/3307 - 269s - loss: 0.1489 - auc: 0.9781 - precision: 0.9624 - recall: 0.9571 - val_loss: 0.0825 - val_auc: 0.9598 - val_precision: 0.9537 - val_recall: 0.9506
#
# Epoch 11/30
# 3307/3307 - 268s - loss: 0.1360 - auc: 0.9808 - precision: 0.9728 - recall: 0.9599 - val_loss: 0.0696 - val_auc: 0.9685 - val_precision: 0.9662 - val_recall: 0.9536
#
# Epoch 12/30
# 3307/3307 - 268s - loss: 0.1338 - auc: 0.9813 - precision: 0.9749 - recall: 0.9601 - val_loss: 0.0713 - val_auc: 0.9667 - val_precision: 0.9674 - val_recall: 0.9519
#
# Epoch 13/30
# 3307/3307 - 267s - loss: 0.1357 - auc: 0.9810 - precision: 0.9725 - recall: 0.9598 - val_loss: 0.0817 - val_auc: 0.9609 - val_precision: 0.9512 - val_recall: 0.9541
#
# Epoch 14/30
# 3307/3307 - 265s - loss: 0.1388 - auc: 0.9805 - precision: 0.9690 - recall: 0.9593 - val_loss: 0.0736 - val_auc: 0.9627 - val_precision: 0.9567 - val_recall: 0.9511
#
# Epoch 15/30
# 3307/3307 - 264s - loss: 0.1341 - auc: 0.9813 - precision: 0.9742 - recall: 0.9602 - val_loss: 0.0674 - val_auc: 0.9686 - val_precision: 0.9656 - val_recall: 0.9540
#
# Epoch 16/30
# 3307/3307 - 265s - loss: 0.1344 - auc: 0.9813 - precision: 0.9735 - recall: 0.9600 - val_loss: 0.0659 - val_auc: 0.9671 - val_precision: 0.9673 - val_recall: 0.9529
#
# Epoch 17/30
# 3307/3307 - 277s - loss: 0.1380 - auc: 0.9808 - precision: 0.9699 - recall: 0.9593 - val_loss: 0.0729 - val_auc: 0.9651 - val_precision: 0.9639 - val_recall: 0.9535
#
# Epoch 18/30
# 3307/3307 - 269s - loss: 0.1357 - auc: 0.9810 - precision: 0.9725 - recall: 0.9598 - val_loss: 0.0720 - val_auc: 0.9667 - val_precision: 0.9639 - val_recall: 0.9535
#
# Epoch 19/30
# 3307/3307 - 270s - loss: 0.1330 - auc: 0.9816 - precision: 0.9748 - recall: 0.9602 - val_loss: 0.0671 - val_auc: 0.9680 - val_precision: 0.9670 - val_recall: 0.9536
#
# Epoch 20/30
# 3307/3307 - 274s - loss: 0.1331 - auc: 0.9816 - precision: 0.9747 - recall: 0.9602 - val_loss: 0.0689 - val_auc: 0.9685 - val_precision: 0.9657 - val_recall: 0.9537
#
# Epoch 21/30
# 3307/3307 - 281s - loss: 0.1329 - auc: 0.9817 - precision: 0.9746 - recall: 0.9603 - val_loss: 0.0657 - val_auc: 0.9691 - val_precision: 0.9651 - val_recall: 0.9539
#
# Epoch 22/30
# 3307/3307 - 282s - loss: 0.1350 - auc: 0.9813 - precision: 0.9719 - recall: 0.9601 - val_loss: 0.0710 - val_auc: 0.9663 - val_precision: 0.9642 - val_recall: 0.9540
#
# Epoch 23/30
# 3307/3307 - 275s - loss: 0.1335 - auc: 0.9816 - precision: 0.9739 - recall: 0.9602 - val_loss: 0.0649 - val_auc: 0.9684 - val_precision: 0.9774 - val_recall: 0.9486
#
# Epoch 24/30
# 3307/3307 - 272s - loss: 0.1331 - auc: 0.9816 - precision: 0.9740 - recall: 0.9602 - val_loss: 0.0651 - val_auc: 0.9685 - val_precision: 0.9669 - val_recall: 0.9537
#
# Epoch 25/30
# 3307/3307 - 276s - loss: 0.1323 - auc: 0.9818 - precision: 0.9747 - recall: 0.9603 - val_loss: 0.0729 - val_auc: 0.9658 - val_precision: 0.9604 - val_recall: 0.9542
#
# Epoch 26/30
# 3307/3307 - 274s - loss: 0.1327 - auc: 0.9817 - precision: 0.9744 - recall: 0.9604 - val_loss: 0.0658 - val_auc: 0.9686 - val_precision: 0.9672 - val_recall: 0.9533
#
# Epoch 27/30
# 3307/3307 - 274s - loss: 0.1345 - auc: 0.9815 - precision: 0.9724 - recall: 0.9600 - val_loss: 0.0730 - val_auc: 0.9661 - val_precision: 0.9606 - val_recall: 0.9536
#
# Epoch 28/30
# 3307/3307 - 281s - loss: 0.1330 - auc: 0.9816 - precision: 0.9739 - recall: 0.9603 - val_loss: 0.0663 - val_auc: 0.9687 - val_precision: 0.9674 - val_recall: 0.9534
#
# Epoch 29/30
# 3307/3307 - 290s - loss: 0.1305 - auc: 0.9822 - precision: 0.9754 - recall: 0.9607 - val_loss: 0.0663 - val_auc: 0.9692 - val_precision: 0.9664 - val_recall: 0.9540
#
# Epoch 30/30
# 3307/3307 - 281s - loss: 0.1303 - auc: 0.9823 - precision: 0.9753 - recall: 0.9608 - val_loss: 0.0666 - val_auc: 0.9692 - val_precision: 0.9667 - val_recall: 0.9540
#
# Best loss: 0.06490981578826904
# Model: models5/bdbc5bf2-c04e-49b6-b5dd-af53464f1556.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.42069079309373686, 'epochs': 30, 'nr_layers': 2.0, 'nr_units': 900.0, 'optimizer': {'lr_mult': 1.9780494029450952, 'name': 'adam'}}
# Epoch 1/30
# 3307/3307 - 149s - loss: 0.2137 - auc: 0.9646 - precision: 0.9064 - recall: 0.9501 - val_loss: 0.0809 - val_auc: 0.9709 - val_precision: 0.9227 - val_recall: 0.9477
#
# Epoch 2/30
# 3307/3307 - 147s - loss: 0.1717 - auc: 0.9756 - precision: 0.9363 - recall: 0.9546 - val_loss: 0.0749 - val_auc: 0.9704 - val_precision: 0.9327 - val_recall: 0.9474
#
# Epoch 3/30
# 3307/3307 - 148s - loss: 0.1647 - auc: 0.9765 - precision: 0.9457 - recall: 0.9546 - val_loss: 0.1092 - val_auc: 0.9704 - val_precision: 0.8555 - val_recall: 0.9558
#
# Epoch 4/30
# 3307/3307 - 146s - loss: 0.1605 - auc: 0.9771 - precision: 0.9540 - recall: 0.9543 - val_loss: 0.0627 - val_auc: 0.9730 - val_precision: 0.9597 - val_recall: 0.9476
#
# Epoch 5/30
# 3307/3307 - 146s - loss: 0.1569 - auc: 0.9777 - precision: 0.9588 - recall: 0.9547 - val_loss: 0.0729 - val_auc: 0.9734 - val_precision: 0.9595 - val_recall: 0.9482
#
# Epoch 6/30
# 3307/3307 - 147s - loss: 0.1540 - auc: 0.9781 - precision: 0.9617 - recall: 0.9556 - val_loss: 0.0773 - val_auc: 0.9718 - val_precision: 0.9504 - val_recall: 0.9537
#
# Epoch 7/30
# 3307/3307 - 148s - loss: 0.1522 - auc: 0.9784 - precision: 0.9637 - recall: 0.9561 - val_loss: 0.0638 - val_auc: 0.9727 - val_precision: 0.9575 - val_recall: 0.9535
#
# Epoch 8/30
# 3307/3307 - 150s - loss: 0.1510 - auc: 0.9785 - precision: 0.9648 - recall: 0.9567 - val_loss: 0.0748 - val_auc: 0.9741 - val_precision: 0.9615 - val_recall: 0.9483
#
# Epoch 9/30
# 3307/3307 - 153s - loss: 0.1496 - auc: 0.9788 - precision: 0.9661 - recall: 0.9571 - val_loss: 0.0796 - val_auc: 0.9713 - val_precision: 0.9403 - val_recall: 0.9461
#
# Epoch 10/30
# 3307/3307 - 152s - loss: 0.1435 - auc: 0.9800 - precision: 0.9696 - recall: 0.9589 - val_loss: 0.0699 - val_auc: 0.9750 - val_precision: 0.9585 - val_recall: 0.9540
#
# Epoch 11/30
# 3307/3307 - 151s - loss: 0.1428 - auc: 0.9802 - precision: 0.9698 - recall: 0.9592 - val_loss: 0.0644 - val_auc: 0.9749 - val_precision: 0.9598 - val_recall: 0.9540
#
# Epoch 12/30
# 3307/3307 - 151s - loss: 0.1424 - auc: 0.9802 - precision: 0.9700 - recall: 0.9593 - val_loss: 0.0639 - val_auc: 0.9748 - val_precision: 0.9612 - val_recall: 0.9523
#
# Epoch 13/30
# 3307/3307 - 156s - loss: 0.1420 - auc: 0.9803 - precision: 0.9702 - recall: 0.9593 - val_loss: 0.0678 - val_auc: 0.9750 - val_precision: 0.9604 - val_recall: 0.9537
#
# Epoch 14/30
# 3307/3307 - 156s - loss: 0.1418 - auc: 0.9803 - precision: 0.9702 - recall: 0.9594 - val_loss: 0.0661 - val_auc: 0.9750 - val_precision: 0.9607 - val_recall: 0.9536
#
# Epoch 15/30
# 3307/3307 - 153s - loss: 0.1404 - auc: 0.9806 - precision: 0.9708 - recall: 0.9599 - val_loss: 0.0671 - val_auc: 0.9752 - val_precision: 0.9612 - val_recall: 0.9539
#
# Epoch 16/30
# 3307/3307 - 152s - loss: 0.1401 - auc: 0.9807 - precision: 0.9708 - recall: 0.9600 - val_loss: 0.0661 - val_auc: 0.9754 - val_precision: 0.9621 - val_recall: 0.9538
#
# Epoch 17/30
# 3307/3307 - 152s - loss: 0.1400 - auc: 0.9807 - precision: 0.9707 - recall: 0.9599 - val_loss: 0.0655 - val_auc: 0.9753 - val_precision: 0.9614 - val_recall: 0.9540
#
# Epoch 18/30
# 3307/3307 - 154s - loss: 0.1400 - auc: 0.9807 - precision: 0.9709 - recall: 0.9600 - val_loss: 0.0635 - val_auc: 0.9754 - val_precision: 0.9628 - val_recall: 0.9538
#
# Epoch 19/30
# 3307/3307 - 152s - loss: 0.1399 - auc: 0.9807 - precision: 0.9708 - recall: 0.9600 - val_loss: 0.0655 - val_auc: 0.9754 - val_precision: 0.9625 - val_recall: 0.9538
#
# Epoch 20/30
# 3307/3307 - 152s - loss: 0.1398 - auc: 0.9807 - precision: 0.9709 - recall: 0.9601 - val_loss: 0.0655 - val_auc: 0.9754 - val_precision: 0.9620 - val_recall: 0.9539
#
# Epoch 21/30
# 3307/3307 - 151s - loss: 0.1396 - auc: 0.9808 - precision: 0.9708 - recall: 0.9601 - val_loss: 0.0649 - val_auc: 0.9754 - val_precision: 0.9631 - val_recall: 0.9538
#
# Epoch 22/30
# 3307/3307 - 150s - loss: 0.1396 - auc: 0.9808 - precision: 0.9708 - recall: 0.9601 - val_loss: 0.0659 - val_auc: 0.9754 - val_precision: 0.9626 - val_recall: 0.9539
#
# Epoch 23/30
# 3307/3307 - 151s - loss: 0.1396 - auc: 0.9808 - precision: 0.9709 - recall: 0.9601 - val_loss: 0.0658 - val_auc: 0.9753 - val_precision: 0.9620 - val_recall: 0.9539
#
# Epoch 24/30
# 3307/3307 - 151s - loss: 0.1395 - auc: 0.9808 - precision: 0.9709 - recall: 0.9601 - val_loss: 0.0645 - val_auc: 0.9755 - val_precision: 0.9632 - val_recall: 0.9538
#
# Epoch 25/30
# 3307/3307 - 152s - loss: 0.1394 - auc: 0.9808 - precision: 0.9710 - recall: 0.9602 - val_loss: 0.0656 - val_auc: 0.9754 - val_precision: 0.9627 - val_recall: 0.9539
#
# Epoch 26/30
# 3307/3307 - 152s - loss: 0.1394 - auc: 0.9809 - precision: 0.9710 - recall: 0.9602 - val_loss: 0.0648 - val_auc: 0.9754 - val_precision: 0.9625 - val_recall: 0.9539
#
# Epoch 27/30
# 3307/3307 - 146s - loss: 0.1394 - auc: 0.9808 - precision: 0.9710 - recall: 0.9602 - val_loss: 0.0648 - val_auc: 0.9754 - val_precision: 0.9628 - val_recall: 0.9539
#
# Epoch 28/30
# 3307/3307 - 145s - loss: 0.1396 - auc: 0.9808 - precision: 0.9708 - recall: 0.9601 - val_loss: 0.0651 - val_auc: 0.9754 - val_precision: 0.9627 - val_recall: 0.9538
#
# Epoch 29/30
# 3307/3307 - 152s - loss: 0.1396 - auc: 0.9808 - precision: 0.9710 - recall: 0.9602 - val_loss: 0.0654 - val_auc: 0.9754 - val_precision: 0.9627 - val_recall: 0.9539
#
# Epoch 30/30
# 3307/3307 - 147s - loss: 0.1394 - auc: 0.9808 - precision: 0.9709 - recall: 0.9601 - val_loss: 0.0651 - val_auc: 0.9754 - val_precision: 0.9627 - val_recall: 0.9539
#
# Best loss: 0.06271379441022873
# Model: models5/6a863805-1eca-42e2-b192-a2a4cc0c8d29.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'selu', 'batch_size': 4096, 'dropout_rate': 0.06077254770921764, 'epochs': 30, 'nr_layers': 4.0, 'nr_units': 700.0, 'optimizer': {'lr_mult': 2.171783790121056, 'name': 'sgd'}}
# Epoch 1/30
# 3307/3307 - 215s - loss: 0.1902 - auc: 0.9707 - precision: 0.9227 - recall: 0.9512 - val_loss: 0.0731 - val_auc: 0.9702 - val_precision: 0.9313 - val_recall: 0.9479
#
# Epoch 2/30
# 3307/3307 - 211s - loss: 0.1594 - auc: 0.9770 - precision: 0.9544 - recall: 0.9545 - val_loss: 0.0771 - val_auc: 0.9689 - val_precision: 0.9486 - val_recall: 0.9479
#
# Epoch 3/30
# 3307/3307 - 215s - loss: 0.1569 - auc: 0.9774 - precision: 0.9554 - recall: 0.9546 - val_loss: 0.1007 - val_auc: 0.9706 - val_precision: 0.8765 - val_recall: 0.9552
#
# Epoch 4/30
# 3307/3307 - 217s - loss: 0.1554 - auc: 0.9777 - precision: 0.9561 - recall: 0.9547 - val_loss: 0.0721 - val_auc: 0.9718 - val_precision: 0.9447 - val_recall: 0.9484
#
# Epoch 5/30
# 3307/3307 - 218s - loss: 0.1546 - auc: 0.9780 - precision: 0.9565 - recall: 0.9546 - val_loss: 0.0781 - val_auc: 0.9668 - val_precision: 0.9344 - val_recall: 0.9483
#
# Epoch 6/30
# 3307/3307 - 220s - loss: 0.1540 - auc: 0.9783 - precision: 0.9572 - recall: 0.9544 - val_loss: 0.1019 - val_auc: 0.9659 - val_precision: 0.9175 - val_recall: 0.9490
#
# Epoch 7/30
# 3307/3307 - 215s - loss: 0.1536 - auc: 0.9786 - precision: 0.9576 - recall: 0.9543 - val_loss: 0.0722 - val_auc: 0.9694 - val_precision: 0.9375 - val_recall: 0.9479
#
# Epoch 8/30
# 3307/3307 - 214s - loss: 0.1526 - auc: 0.9787 - precision: 0.9586 - recall: 0.9544 - val_loss: 0.0704 - val_auc: 0.9702 - val_precision: 0.9506 - val_recall: 0.9477
#
# Epoch 9/30
# 3307/3307 - 214s - loss: 0.1513 - auc: 0.9788 - precision: 0.9596 - recall: 0.9546 - val_loss: 0.0748 - val_auc: 0.9708 - val_precision: 0.9386 - val_recall: 0.9480
#
# Epoch 10/30
# 3307/3307 - 214s - loss: 0.1501 - auc: 0.9789 - precision: 0.9589 - recall: 0.9553 - val_loss: 0.0670 - val_auc: 0.9738 - val_precision: 0.9567 - val_recall: 0.9480
#
# Epoch 11/30
# 3307/3307 - 215s - loss: 0.1492 - auc: 0.9789 - precision: 0.9572 - recall: 0.9567 - val_loss: 0.0691 - val_auc: 0.9729 - val_precision: 0.9344 - val_recall: 0.9533
#
# Epoch 12/30
# 3307/3307 - 223s - loss: 0.1483 - auc: 0.9792 - precision: 0.9558 - recall: 0.9574 - val_loss: 0.0681 - val_auc: 0.9737 - val_precision: 0.9487 - val_recall: 0.9534
#
# Epoch 13/30
# 3307/3307 - 226s - loss: 0.1474 - auc: 0.9795 - precision: 0.9567 - recall: 0.9578 - val_loss: 0.0901 - val_auc: 0.9695 - val_precision: 0.8991 - val_recall: 0.9538
#
# Epoch 14/30
# 3307/3307 - 216s - loss: 0.1470 - auc: 0.9795 - precision: 0.9568 - recall: 0.9579 - val_loss: 0.0791 - val_auc: 0.9743 - val_precision: 0.9589 - val_recall: 0.9540
#
# Epoch 15/30
# 3307/3307 - 213s - loss: 0.1481 - auc: 0.9793 - precision: 0.9564 - recall: 0.9576 - val_loss: 0.0792 - val_auc: 0.9715 - val_precision: 0.9335 - val_recall: 0.9520
#
# Epoch 16/30
# 3307/3307 - 216s - loss: 0.1354 - auc: 0.9814 - precision: 0.9692 - recall: 0.9610 - val_loss: 0.0579 - val_auc: 0.9751 - val_precision: 0.9639 - val_recall: 0.9535
#
# Epoch 17/30
# 3307/3307 - 214s - loss: 0.1342 - auc: 0.9815 - precision: 0.9704 - recall: 0.9611 - val_loss: 0.0582 - val_auc: 0.9749 - val_precision: 0.9634 - val_recall: 0.9537
#
# Epoch 18/30
# 3307/3307 - 214s - loss: 0.1339 - auc: 0.9815 - precision: 0.9707 - recall: 0.9611 - val_loss: 0.0590 - val_auc: 0.9750 - val_precision: 0.9632 - val_recall: 0.9536
#
# Epoch 19/30
# 3307/3307 - 213s - loss: 0.1337 - auc: 0.9816 - precision: 0.9708 - recall: 0.9611 - val_loss: 0.0574 - val_auc: 0.9751 - val_precision: 0.9662 - val_recall: 0.9531
#
# Epoch 20/30
# 3307/3307 - 213s - loss: 0.1336 - auc: 0.9816 - precision: 0.9709 - recall: 0.9611 - val_loss: 0.0625 - val_auc: 0.9745 - val_precision: 0.9516 - val_recall: 0.9543
#
# Epoch 21/30
# 3307/3307 - 217s - loss: 0.1336 - auc: 0.9816 - precision: 0.9710 - recall: 0.9611 - val_loss: 0.0621 - val_auc: 0.9752 - val_precision: 0.9630 - val_recall: 0.9538
#
# Epoch 22/30
# 3307/3307 - 215s - loss: 0.1334 - auc: 0.9817 - precision: 0.9710 - recall: 0.9611 - val_loss: 0.0599 - val_auc: 0.9746 - val_precision: 0.9634 - val_recall: 0.9538
#
# Epoch 23/30
# 3307/3307 - 216s - loss: 0.1333 - auc: 0.9817 - precision: 0.9710 - recall: 0.9612 - val_loss: 0.0587 - val_auc: 0.9751 - val_precision: 0.9632 - val_recall: 0.9539
#
# Epoch 24/30
# 3307/3307 - 214s - loss: 0.1332 - auc: 0.9818 - precision: 0.9711 - recall: 0.9612 - val_loss: 0.0561 - val_auc: 0.9751 - val_precision: 0.9659 - val_recall: 0.9536
#
# Epoch 25/30
# 3307/3307 - 214s - loss: 0.1331 - auc: 0.9818 - precision: 0.9712 - recall: 0.9612 - val_loss: 0.0584 - val_auc: 0.9752 - val_precision: 0.9647 - val_recall: 0.9538
#
# Epoch 26/30
# 3307/3307 - 214s - loss: 0.1330 - auc: 0.9818 - precision: 0.9713 - recall: 0.9612 - val_loss: 0.0606 - val_auc: 0.9754 - val_precision: 0.9658 - val_recall: 0.9532
#
# Epoch 27/30
# 3307/3307 - 218s - loss: 0.1329 - auc: 0.9819 - precision: 0.9714 - recall: 0.9611 - val_loss: 0.0618 - val_auc: 0.9751 - val_precision: 0.9619 - val_recall: 0.9542
#
# Epoch 28/30
# 3307/3307 - 220s - loss: 0.1329 - auc: 0.9819 - precision: 0.9714 - recall: 0.9611 - val_loss: 0.0588 - val_auc: 0.9751 - val_precision: 0.9660 - val_recall: 0.9537
#
# Epoch 29/30
# 3307/3307 - 224s - loss: 0.1328 - auc: 0.9819 - precision: 0.9715 - recall: 0.9611 - val_loss: 0.0627 - val_auc: 0.9752 - val_precision: 0.9627 - val_recall: 0.9540
#
# Epoch 30/30
# 3307/3307 - 218s - loss: 0.1320 - auc: 0.9822 - precision: 0.9717 - recall: 0.9613 - val_loss: 0.0601 - val_auc: 0.9755 - val_precision: 0.9649 - val_recall: 0.9538
#
# Best loss: 0.05612509697675705
# Model: models5/117c826d-1316-4db6-8edf-a9797856c110.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.13096523469482935, 'epochs': 30, 'nr_layers': 6.0, 'nr_units': 300.0, 'optimizer': {'lr_mult': 2.0067799165492843, 'name': 'sgd'}}
# Epoch 1/30
# 3307/3307 - 141s - loss: 0.1785 - auc: 0.9732 - precision: 0.9360 - recall: 0.9523 - val_loss: 0.0760 - val_auc: 0.9692 - val_precision: 0.9381 - val_recall: 0.9476
#
# Epoch 2/30
# 3307/3307 - 137s - loss: 0.1580 - auc: 0.9773 - precision: 0.9569 - recall: 0.9546 - val_loss: 0.0785 - val_auc: 0.9722 - val_precision: 0.9585 - val_recall: 0.9478
#
# Epoch 3/30
# 3307/3307 - 135s - loss: 0.1548 - auc: 0.9780 - precision: 0.9575 - recall: 0.9548 - val_loss: 0.0972 - val_auc: 0.9683 - val_precision: 0.8807 - val_recall: 0.9549
#
# Epoch 4/30
# 3307/3307 - 137s - loss: 0.1527 - auc: 0.9786 - precision: 0.9595 - recall: 0.9548 - val_loss: 0.0782 - val_auc: 0.9713 - val_precision: 0.9373 - val_recall: 0.9478
#
# Epoch 5/30
# 3307/3307 - 139s - loss: 0.1524 - auc: 0.9786 - precision: 0.9594 - recall: 0.9544 - val_loss: 0.0790 - val_auc: 0.9732 - val_precision: 0.9492 - val_recall: 0.9481
#
# Epoch 6/30
# 3307/3307 - 136s - loss: 0.1515 - auc: 0.9788 - precision: 0.9611 - recall: 0.9549 - val_loss: 0.0814 - val_auc: 0.9730 - val_precision: 0.9383 - val_recall: 0.9543
#
# Epoch 7/30
# 3307/3307 - 139s - loss: 0.1394 - auc: 0.9804 - precision: 0.9727 - recall: 0.9570 - val_loss: 0.0675 - val_auc: 0.9742 - val_precision: 0.9679 - val_recall: 0.9476
#
# Epoch 8/30
# 3307/3307 - 139s - loss: 0.1373 - auc: 0.9806 - precision: 0.9730 - recall: 0.9585 - val_loss: 0.0640 - val_auc: 0.9745 - val_precision: 0.9690 - val_recall: 0.9477
#
# Epoch 9/30
# 3307/3307 - 137s - loss: 0.1364 - auc: 0.9808 - precision: 0.9725 - recall: 0.9596 - val_loss: 0.0664 - val_auc: 0.9744 - val_precision: 0.9637 - val_recall: 0.9525
#
# Epoch 10/30
# 3307/3307 - 138s - loss: 0.1357 - auc: 0.9809 - precision: 0.9723 - recall: 0.9602 - val_loss: 0.0662 - val_auc: 0.9747 - val_precision: 0.9644 - val_recall: 0.9536
#
# Epoch 11/30
# 3307/3307 - 138s - loss: 0.1353 - auc: 0.9810 - precision: 0.9721 - recall: 0.9605 - val_loss: 0.0631 - val_auc: 0.9748 - val_precision: 0.9620 - val_recall: 0.9537
#
# Epoch 12/30
# 3307/3307 - 138s - loss: 0.1349 - auc: 0.9811 - precision: 0.9721 - recall: 0.9606 - val_loss: 0.0651 - val_auc: 0.9749 - val_precision: 0.9652 - val_recall: 0.9525
#
# Epoch 13/30
# 3307/3307 - 138s - loss: 0.1346 - auc: 0.9812 - precision: 0.9720 - recall: 0.9607 - val_loss: 0.0662 - val_auc: 0.9744 - val_precision: 0.9579 - val_recall: 0.9533
#
# Epoch 14/30
# 3307/3307 - 138s - loss: 0.1344 - auc: 0.9813 - precision: 0.9720 - recall: 0.9607 - val_loss: 0.0659 - val_auc: 0.9753 - val_precision: 0.9657 - val_recall: 0.9535
#
# Epoch 15/30
# 3307/3307 - 139s - loss: 0.1341 - auc: 0.9814 - precision: 0.9721 - recall: 0.9608 - val_loss: 0.0688 - val_auc: 0.9750 - val_precision: 0.9622 - val_recall: 0.9527
#
# Epoch 16/30
# 3307/3307 - 137s - loss: 0.1340 - auc: 0.9815 - precision: 0.9721 - recall: 0.9608 - val_loss: 0.0630 - val_auc: 0.9754 - val_precision: 0.9649 - val_recall: 0.9535
#
# Epoch 17/30
# 3307/3307 - 137s - loss: 0.1338 - auc: 0.9815 - precision: 0.9721 - recall: 0.9609 - val_loss: 0.0645 - val_auc: 0.9752 - val_precision: 0.9630 - val_recall: 0.9537
#
# Epoch 18/30
# 3307/3307 - 136s - loss: 0.1336 - auc: 0.9816 - precision: 0.9724 - recall: 0.9609 - val_loss: 0.0624 - val_auc: 0.9752 - val_precision: 0.9637 - val_recall: 0.9537
#
# Epoch 19/30
# 3307/3307 - 135s - loss: 0.1334 - auc: 0.9817 - precision: 0.9724 - recall: 0.9609 - val_loss: 0.0630 - val_auc: 0.9757 - val_precision: 0.9660 - val_recall: 0.9525
#
# Epoch 20/30
# 3307/3307 - 135s - loss: 0.1333 - auc: 0.9817 - precision: 0.9725 - recall: 0.9609 - val_loss: 0.0652 - val_auc: 0.9750 - val_precision: 0.9557 - val_recall: 0.9539
#
# Epoch 21/30
# 3307/3307 - 135s - loss: 0.1332 - auc: 0.9817 - precision: 0.9724 - recall: 0.9609 - val_loss: 0.0655 - val_auc: 0.9757 - val_precision: 0.9643 - val_recall: 0.9527
#
# Epoch 22/30
# 3307/3307 - 136s - loss: 0.1434 - auc: 0.9804 - precision: 0.9590 - recall: 0.9597 - val_loss: 0.0672 - val_auc: 0.9744 - val_precision: 0.9579 - val_recall: 0.9542
#
# Epoch 23/30
# 3307/3307 - 138s - loss: 0.1356 - auc: 0.9812 - precision: 0.9710 - recall: 0.9607 - val_loss: 0.0647 - val_auc: 0.9755 - val_precision: 0.9633 - val_recall: 0.9538
#
# Epoch 24/30
# 3307/3307 - 142s - loss: 0.1335 - auc: 0.9816 - precision: 0.9721 - recall: 0.9611 - val_loss: 0.0640 - val_auc: 0.9757 - val_precision: 0.9642 - val_recall: 0.9539
#
# Epoch 25/30
# 3307/3307 - 136s - loss: 0.1333 - auc: 0.9817 - precision: 0.9722 - recall: 0.9611 - val_loss: 0.0665 - val_auc: 0.9757 - val_precision: 0.9640 - val_recall: 0.9539
#
# Epoch 26/30
# 3307/3307 - 138s - loss: 0.1331 - auc: 0.9817 - precision: 0.9722 - recall: 0.9611 - val_loss: 0.0635 - val_auc: 0.9758 - val_precision: 0.9661 - val_recall: 0.9536
#
# Epoch 27/30
# 3307/3307 - 136s - loss: 0.1330 - auc: 0.9818 - precision: 0.9724 - recall: 0.9611 - val_loss: 0.0646 - val_auc: 0.9754 - val_precision: 0.9644 - val_recall: 0.9537
#
# Epoch 28/30
# 3307/3307 - 136s - loss: 0.1328 - auc: 0.9818 - precision: 0.9724 - recall: 0.9611 - val_loss: 0.0634 - val_auc: 0.9759 - val_precision: 0.9661 - val_recall: 0.9537
#
# Epoch 29/30
# 3307/3307 - 134s - loss: 0.1325 - auc: 0.9819 - precision: 0.9723 - recall: 0.9612 - val_loss: 0.0642 - val_auc: 0.9759 - val_precision: 0.9652 - val_recall: 0.9538
#
# Epoch 30/30
# 3307/3307 - 135s - loss: 0.1324 - auc: 0.9820 - precision: 0.9724 - recall: 0.9612 - val_loss: 0.0641 - val_auc: 0.9759 - val_precision: 0.9651 - val_recall: 0.9539
#
# Best loss: 0.062439098954200745
# Model: models5/af740957-35aa-48ce-b346-3b29e619109a.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.07839312373939916, 'epochs': 30, 'nr_layers': 2.0, 'nr_units': 500.0, 'optimizer': {'lr_mult': 0.7363691092644989, 'name': 'nadam'}}
# Epoch 1/30
# 3307/3307 - 94s - loss: 0.2122 - auc: 0.9655 - precision: 0.8954 - recall: 0.9477 - val_loss: 0.0932 - val_auc: 0.9701 - val_precision: 0.8991 - val_recall: 0.9490
#
# Epoch 2/30
# 3307/3307 - 89s - loss: 0.1752 - auc: 0.9745 - precision: 0.9304 - recall: 0.9545 - val_loss: 0.0974 - val_auc: 0.9693 - val_precision: 0.8803 - val_recall: 0.9489
#
# Epoch 3/30
# 3307/3307 - 87s - loss: 0.1610 - auc: 0.9777 - precision: 0.9434 - recall: 0.9556 - val_loss: 0.1019 - val_auc: 0.9717 - val_precision: 0.8675 - val_recall: 0.9557
#
# Epoch 4/30
# 3307/3307 - 89s - loss: 0.1547 - auc: 0.9788 - precision: 0.9525 - recall: 0.9560 - val_loss: 0.0728 - val_auc: 0.9730 - val_precision: 0.9442 - val_recall: 0.9485
#
# Epoch 5/30
# 3307/3307 - 88s - loss: 0.1511 - auc: 0.9792 - precision: 0.9573 - recall: 0.9570 - val_loss: 0.0768 - val_auc: 0.9730 - val_precision: 0.9423 - val_recall: 0.9544
#
# Epoch 6/30
# 3307/3307 - 88s - loss: 0.1486 - auc: 0.9796 - precision: 0.9603 - recall: 0.9578 - val_loss: 0.0893 - val_auc: 0.9731 - val_precision: 0.9243 - val_recall: 0.9550
#
# Epoch 7/30
# 3307/3307 - 88s - loss: 0.1467 - auc: 0.9799 - precision: 0.9624 - recall: 0.9584 - val_loss: 0.0800 - val_auc: 0.9723 - val_precision: 0.9154 - val_recall: 0.9535
#
# Epoch 8/30
# 3307/3307 - 90s - loss: 0.1452 - auc: 0.9801 - precision: 0.9639 - recall: 0.9588 - val_loss: 0.0699 - val_auc: 0.9746 - val_precision: 0.9592 - val_recall: 0.9482
#
# Epoch 9/30
# 3307/3307 - 89s - loss: 0.1438 - auc: 0.9803 - precision: 0.9654 - recall: 0.9592 - val_loss: 0.0681 - val_auc: 0.9750 - val_precision: 0.9596 - val_recall: 0.9524
#
# Epoch 10/30
# 3307/3307 - 90s - loss: 0.1427 - auc: 0.9804 - precision: 0.9665 - recall: 0.9594 - val_loss: 0.0676 - val_auc: 0.9753 - val_precision: 0.9621 - val_recall: 0.9502
#
# Epoch 11/30
# 3307/3307 - 90s - loss: 0.1416 - auc: 0.9806 - precision: 0.9676 - recall: 0.9596 - val_loss: 0.0685 - val_auc: 0.9752 - val_precision: 0.9594 - val_recall: 0.9534
#
# Epoch 12/30
# 3307/3307 - 90s - loss: 0.1408 - auc: 0.9807 - precision: 0.9684 - recall: 0.9597 - val_loss: 0.0701 - val_auc: 0.9734 - val_precision: 0.9587 - val_recall: 0.9484
#
# Epoch 13/30
# 3307/3307 - 89s - loss: 0.1405 - auc: 0.9808 - precision: 0.9683 - recall: 0.9598 - val_loss: 0.0879 - val_auc: 0.9713 - val_precision: 0.8989 - val_recall: 0.9493
#
# Epoch 14/30
# 3307/3307 - 89s - loss: 0.1395 - auc: 0.9809 - precision: 0.9694 - recall: 0.9599 - val_loss: 0.0768 - val_auc: 0.9753 - val_precision: 0.9633 - val_recall: 0.9510
#
# Epoch 15/30
# 3307/3307 - 89s - loss: 0.1394 - auc: 0.9809 - precision: 0.9692 - recall: 0.9599 - val_loss: 0.0728 - val_auc: 0.9739 - val_precision: 0.9478 - val_recall: 0.9527
#
# Epoch 16/30
# 3307/3307 - 88s - loss: 0.1366 - auc: 0.9814 - precision: 0.9709 - recall: 0.9606 - val_loss: 0.0632 - val_auc: 0.9761 - val_precision: 0.9629 - val_recall: 0.9537
#
# Epoch 17/30
# 3307/3307 - 88s - loss: 0.1363 - auc: 0.9815 - precision: 0.9709 - recall: 0.9606 - val_loss: 0.0638 - val_auc: 0.9758 - val_precision: 0.9631 - val_recall: 0.9537
#
# Epoch 18/30
# 3307/3307 - 88s - loss: 0.1362 - auc: 0.9815 - precision: 0.9711 - recall: 0.9606 - val_loss: 0.0627 - val_auc: 0.9760 - val_precision: 0.9627 - val_recall: 0.9538
#
# Epoch 19/30
# 3307/3307 - 89s - loss: 0.1361 - auc: 0.9815 - precision: 0.9711 - recall: 0.9606 - val_loss: 0.0625 - val_auc: 0.9759 - val_precision: 0.9652 - val_recall: 0.9529
#
# Epoch 20/30
# 3307/3307 - 88s - loss: 0.1360 - auc: 0.9815 - precision: 0.9711 - recall: 0.9606 - val_loss: 0.0646 - val_auc: 0.9754 - val_precision: 0.9563 - val_recall: 0.9543
#
# Epoch 21/30
# 3307/3307 - 89s - loss: 0.1359 - auc: 0.9815 - precision: 0.9712 - recall: 0.9606 - val_loss: 0.0674 - val_auc: 0.9758 - val_precision: 0.9619 - val_recall: 0.9531
#
# Epoch 22/30
# 3307/3307 - 89s - loss: 0.1358 - auc: 0.9816 - precision: 0.9712 - recall: 0.9607 - val_loss: 0.0619 - val_auc: 0.9759 - val_precision: 0.9642 - val_recall: 0.9535
#
# Epoch 23/30
# 3307/3307 - 89s - loss: 0.1358 - auc: 0.9816 - precision: 0.9712 - recall: 0.9606 - val_loss: 0.0642 - val_auc: 0.9760 - val_precision: 0.9618 - val_recall: 0.9541
#
# Epoch 24/30
# 3307/3307 - 90s - loss: 0.1356 - auc: 0.9816 - precision: 0.9712 - recall: 0.9607 - val_loss: 0.0611 - val_auc: 0.9761 - val_precision: 0.9644 - val_recall: 0.9539
#
# Epoch 25/30
# 3307/3307 - 91s - loss: 0.1355 - auc: 0.9816 - precision: 0.9713 - recall: 0.9607 - val_loss: 0.0652 - val_auc: 0.9760 - val_precision: 0.9626 - val_recall: 0.9540
#
# Epoch 26/30
# 3307/3307 - 91s - loss: 0.1354 - auc: 0.9816 - precision: 0.9713 - recall: 0.9607 - val_loss: 0.0660 - val_auc: 0.9761 - val_precision: 0.9653 - val_recall: 0.9535
#
# Epoch 27/30
# 3307/3307 - 89s - loss: 0.1354 - auc: 0.9816 - precision: 0.9714 - recall: 0.9607 - val_loss: 0.0666 - val_auc: 0.9758 - val_precision: 0.9602 - val_recall: 0.9537
#
# Epoch 28/30
# 3307/3307 - 90s - loss: 0.1354 - auc: 0.9816 - precision: 0.9714 - recall: 0.9607 - val_loss: 0.0625 - val_auc: 0.9762 - val_precision: 0.9662 - val_recall: 0.9534
#
# Epoch 29/30
# 3307/3307 - 91s - loss: 0.1353 - auc: 0.9817 - precision: 0.9714 - recall: 0.9607 - val_loss: 0.0645 - val_auc: 0.9759 - val_precision: 0.9646 - val_recall: 0.9538
#
# Epoch 30/30
# 3307/3307 - 91s - loss: 0.1347 - auc: 0.9818 - precision: 0.9716 - recall: 0.9609 - val_loss: 0.0656 - val_auc: 0.9763 - val_precision: 0.9636 - val_recall: 0.9540
#
# Best loss: 0.061131563037633896
# Model: models5/e8ac7a57-f1a2-47a6-9b0f-6e52d2a70024.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.3958737104109064, 'epochs': 30, 'nr_layers': 3.0, 'nr_units': 900.0, 'optimizer': {'lr_mult': 1.0694333984136957, 'name': 'nadam'}}
# Epoch 1/30
# 3307/3307 - 244s - loss: 0.2636 - auc: 0.9556 - precision: 0.8725 - recall: 0.9358 - val_loss: 0.1095 - val_auc: 0.9648 - val_precision: 0.9466 - val_recall: 0.9415
#
# Epoch 2/30
# 3307/3307 - 242s - loss: 0.1960 - auc: 0.9712 - precision: 0.9296 - recall: 0.9445 - val_loss: 0.0937 - val_auc: 0.9657 - val_precision: 0.9354 - val_recall: 0.9474
#
# Epoch 3/30
# 3307/3307 - 241s - loss: 0.1783 - auc: 0.9735 - precision: 0.9475 - recall: 0.9487 - val_loss: 0.1150 - val_auc: 0.9668 - val_precision: 0.8602 - val_recall: 0.9554
#
# Epoch 4/30
# 3307/3307 - 246s - loss: 0.1604 - auc: 0.9759 - precision: 0.9640 - recall: 0.9517 - val_loss: 0.0787 - val_auc: 0.9704 - val_precision: 0.9478 - val_recall: 0.9483
#
# Epoch 5/30
# 3307/3307 - 244s - loss: 0.1546 - auc: 0.9768 - precision: 0.9634 - recall: 0.9543 - val_loss: 0.0750 - val_auc: 0.9727 - val_precision: 0.9658 - val_recall: 0.9441
#
# Epoch 6/30
# 3307/3307 - 241s - loss: 0.1531 - auc: 0.9771 - precision: 0.9637 - recall: 0.9550 - val_loss: 0.1431 - val_auc: 0.9685 - val_precision: 0.8718 - val_recall: 0.9550
#
# Epoch 7/30
# 3307/3307 - 238s - loss: 0.1550 - auc: 0.9764 - precision: 0.9650 - recall: 0.9548 - val_loss: 0.0779 - val_auc: 0.9716 - val_precision: 0.9282 - val_recall: 0.9546
#
# Epoch 8/30
# 3307/3307 - 238s - loss: 0.1520 - auc: 0.9772 - precision: 0.9657 - recall: 0.9550 - val_loss: 0.0652 - val_auc: 0.9745 - val_precision: 0.9831 - val_recall: 0.9413
#
# Epoch 9/30
# 3307/3307 - 236s - loss: 0.1512 - auc: 0.9773 - precision: 0.9655 - recall: 0.9554 - val_loss: 0.0744 - val_auc: 0.9740 - val_precision: 0.9548 - val_recall: 0.9541
#
# Epoch 10/30
# 3307/3307 - 237s - loss: 0.1497 - auc: 0.9775 - precision: 0.9667 - recall: 0.9563 - val_loss: 0.0681 - val_auc: 0.9729 - val_precision: 0.9571 - val_recall: 0.9535
#
# Epoch 11/30
# 3307/3307 - 238s - loss: 0.1498 - auc: 0.9773 - precision: 0.9666 - recall: 0.9564 - val_loss: 0.0667 - val_auc: 0.9731 - val_precision: 0.9574 - val_recall: 0.9528
#
# Epoch 12/30
# 3307/3307 - 240s - loss: 0.1527 - auc: 0.9768 - precision: 0.9678 - recall: 0.9547 - val_loss: 0.0726 - val_auc: 0.9731 - val_precision: 0.9505 - val_recall: 0.9540
#
# Epoch 13/30
# 3307/3307 - 238s - loss: 0.1508 - auc: 0.9772 - precision: 0.9667 - recall: 0.9561 - val_loss: 0.0794 - val_auc: 0.9719 - val_precision: 0.9541 - val_recall: 0.9485
#
# Epoch 14/30
# 3307/3307 - 239s - loss: 0.1396 - auc: 0.9796 - precision: 0.9746 - recall: 0.9583 - val_loss: 0.0689 - val_auc: 0.9743 - val_precision: 0.9676 - val_recall: 0.9532
#
# Epoch 15/30
# 3307/3307 - 240s - loss: 0.1364 - auc: 0.9803 - precision: 0.9751 - recall: 0.9595 - val_loss: 0.0659 - val_auc: 0.9749 - val_precision: 0.9647 - val_recall: 0.9538
#
# Epoch 16/30
# 3307/3307 - 243s - loss: 0.1353 - auc: 0.9807 - precision: 0.9751 - recall: 0.9597 - val_loss: 0.0583 - val_auc: 0.9757 - val_precision: 0.9665 - val_recall: 0.9533
#
# Epoch 17/30
# 3307/3307 - 240s - loss: 0.1368 - auc: 0.9807 - precision: 0.9754 - recall: 0.9598 - val_loss: 0.0590 - val_auc: 0.9750 - val_precision: 0.9773 - val_recall: 0.9492
#
# Epoch 18/30
# 3307/3307 - 236s - loss: 0.1343 - auc: 0.9810 - precision: 0.9755 - recall: 0.9599 - val_loss: 0.0617 - val_auc: 0.9751 - val_precision: 0.9663 - val_recall: 0.9537
#
# Epoch 19/30
# 3307/3307 - 235s - loss: 0.1341 - auc: 0.9811 - precision: 0.9754 - recall: 0.9600 - val_loss: 0.0596 - val_auc: 0.9754 - val_precision: 0.9679 - val_recall: 0.9529
#
# Epoch 20/30
#  12%|█▏        | 6/50 [10:38:53<60:55:09, 4984.31s/trial, best loss: 0.05612509697675705]

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Training Results
#
# After completion of the hyperparameter search process, we plot the chosen parameter spaces. The selected values of the ten best performing models are colorized.
# From the graphs we can infer the following optimal parameter spaces:
# * Number of layers: the optimal number of layers seems to be in the interval of `[4, 6]`.
# * Number of units: the optimal number of units per layer seems to be in the interval of `[300, 400]`.
# * Activation function: the activation function `elu` should be preferred, as it was used for all of the best ten models.
# * Dropout rate: a dropout rate `<0.3` seems to perform the best.
# * Optimizer: the `Adam` optimizer was used for all of the ten best performing models.
# * Learning rate multiplier: the learning rate multiplier seems to perform best if kept `<1.1`.

# %%
plt.figure(figsize=(20, 5))
main_plot_history(trials)

plt.figure(figsize=(20, 20))
main_plot_vars(trials, columns=3, colorize_best=10, arrange_by_loss=False)
# Out:
# avg best error: 0.13028952267457333
# finite loss range 0.13028952267457333 0.7716237019156418 0.13131302273812773

# %% [markdown]
# ### Best Model Parameters
#
# The best model has the following parameter configuration:
# * `5` layers,
# * `300` units per layer,
# * a dropout rate of `0.22`,
# * `elu` activation function,
# * `Adam` optimizer,
# * learning rate multiplier of `0.61` effectively reducing the default learning rate of `0.001` to `0.00061`.

# %%
print('Best validation loss: {}\n'.format(np.min(trials.losses())))
print('Best model parameters:')
print('======================')
best_run
# Out:
# Best validation loss: 0.13028952267457333
#
# Best model parameters:
# ======================
# {'activation': 0,
#  'adam_lr_rate_mult': 0.61157158868869,
#  'batch_size': 0,
#  'dropout_rate': 0.22339774943469998,
#  'epochs': 0,
#  'nr_layers': 5.0,
#  'nr_units': 300.0,
#  'optimizer': 1}

# %%
best_model_path = trials.results[np.argmin(trials.losses())]['model_name']
print('Best model path: "{}"'.format(best_model_path))
best_model = models.load_model(best_model_path)
# Out:
# Best model path: "models/c0cb0656-558f-4311-b138-9b91ab4d1fe6.h5"

# %% [markdown]
# ### Performance
#
# The optimized model has an insignificantly higher PR score of `0.97793` compared to the static model with a score of `0.97735`.

# %%
pred_val_score = predict_proba(best_model, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9779380329781184

# %% [markdown]
# ### 4.2 Search-Space restriction and Training
#
# As a second optimization step, we use the optimal parameter values discovered in the first round of hyperparameter search, to conduct another round of hyperparameter search on a restricted search space. This allows us to further explore the optimal parameter space.
# For this round of hyperparameter optimization we use a variable batch size and conduct `20` trials.

# %%
trials = Trials()

space = { 
    'epochs': hp.choice('epochs', [30]),  
    'batch_size': hp.quniform('batch_size', 512, 4096, 10),
    'nr_layers': hp.quniform('nr_layers', 4, 6, 1),  
    'nr_units': hp.quniform('nr_units', 300, 400, 100), 
    'activation': hp.choice('activation', ['elu']),
    'dropout_rate': hp.uniform('dropout_rate', 0, 0.3),
    'optimizer': hp.choice('optimizer', [
        {
            'name': 'adam',
            'lr_mult': hp.loguniform('adam_lr_rate_mult', -0.5, 1),
        }
    ])
}


best_run = fmin(fn=train_dynamic_model,
                space=space,
                algo=tpe.suggest,
                max_evals=20,
                trials=trials)

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# Unfortunately, the second round of hyperparameter search did not yield a better result, as the loss of the best model is recorded with `0.1306`, compared to the loss of `0.1302` obtained from the best model of the first round.
# The difference in the losses is negligible though, suggesting that we have found a good configuration for our model.

# %%
plt.figure(figsize=(20, 5))
main_plot_history(trials)

plt.figure(figsize=(20, 20))
main_plot_vars(trials, columns=3, colorize_best=10, arrange_by_loss=False)
# Out:
# avg best error: 0.13063318593310846
# finite loss range 0.13063318593310846 0.14781879949703883 0.1318917911982782

# %% [markdown]
# ### 4.3 Training a Model with Optimal Parameters
#
# In the last step of this section, we will use the optimal parameter values and model configuration, determined during the first round of hyperparameter search. We train a model using the optimal parameters for `200` epochs, with the objective of obtaining a better performance.

# %%
def train_optimized_model(X_train, y_train, X_val, y_val, model_path, epochs, batch_size, class_weights):    
    input_dims = X_train.shape[1]

    K.clear_session()
    gc.collect()
    
    nr_layers = 5
    nr_units = 300
    dropout_rate = 0.22339774943469998
    lr = (0.001 * 0.61157158868869)

    model = create_model(input_dims=input_dims,
                         nr_layers=nr_layers,
                         nr_units=nr_units,
                         activation='elu',
                         kerner_initializer='he_normal',
                         dropout_layer=layers.Dropout(dropout_rate),
                         optimizer=optimizers.Adam(lr=lr))

    print(model.summary())
    
    mc = callbacks.ModelCheckpoint(filepath=model_path, save_best_only=True)
    
    early_stopping = callbacks.EarlyStopping(patience=50)

    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=5)
    
    hist = model.fit(x=X_train, 
                     y=y_train,
                     validation_data=(X_val, y_val),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[mc, lr_scheduler])
    
    return model, hist

# %%
opt_model, hist = train_optimized_model(X_train, 
                                        y_train_is_attack, 
                                        X_val, 
                                        y_val.label_is_attack.values,
                                        'models5/opt_model.h5',
                                        epochs=200,
                                        batch_size=4096,
                                        class_weights=class_weights)

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the learning curves, we observe that the model does not significantly overfit the training set.

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# After training, we obtain a model with a slightly lower loss of `0.1298` and a better PR score of `0.97816` compared to the best model found during hyperparameter search, with a loss of `0.1302` and a PR score of `0.97793`.

# %%
opt_model = models.load_model('models5/opt_model.h5')
pred_val_score = predict_proba(opt_model, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9781612882599011

# %%
pred_val = predict(opt_model, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.991     0.993     0.992   1348471
#            1      0.967     0.954     0.960    274823
#
#     accuracy                          0.987   1623294
#    macro avg      0.979     0.974     0.976   1623294
# weighted avg      0.987     0.987     0.987   1623294
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                         misclassified    total  percent_misclassified
# Infilteration                   12466    16193               0.769839
# SQL Injection                       2        9               0.222222
# Brute Force -Web                    3       61               0.049180
# Brute Force -XSS                    1       23               0.043478
# Benign                           8966  1348471               0.006649
# DoS attacks-Slowloris               6     1099               0.005460
# Bot                               104    28619               0.003634
# DDoS attacks-LOIC-HTTP             45    57619               0.000781
# SSH-Bruteforce                      2    18759               0.000107

# %% [markdown]
# ## 5. Model Comparison
#
# The model obtained during hyperparameter optimization has a higher PR score of `0.97816` compared to the static model, having a score of `0.97735`.
# Precision and recall are very similar, with values of `0.967` for precision and `0.954` for recall.
# However, both the number of false-positives and the number of false-negatives are lower for the optimized model, as illustrated in the following table:
#
# |Model|PR Score|Precision Positive|Recall Positive|False-Positives|False-Negatives|
# |---|---|---|---|---|---|
# |Static model (no class-weights)|0.97718|**0.992**|0.939|**1956**|16898|
# |Static model (class-weights)|0.97735|0.965|0.954|9375|12649|
# |Optimized model (class-weights)|**0.97816**|0.967|**0.954**|8966|**12629**|
#
# Given the superior performance of the optimized model, we choose to use the this model going forward.

# %% [markdown]
# ## 6. Conclusion
#
# In this notebook, we explored two approaches of training a deep neural network for the task of binary classification of network traffic, concluding that training should be performed taking class imbalance into account, in order to minimize the amount of false-negatives.
# Furthermore, we conducted hyperparameter search and optimization to explore the optimal network architecture and parameter configuration, resulting in a model with compelling performance.
# Even though the model seems to work well on most types of network attacks, it fails to correctly identify infiltration attacks, misclassifiying `77%` of all infiltration traffic as benign traffic. This could be explained by the simmilarity of feature statistics observed in these two kinds of network traffic.
# As a result, other approaches to reliably detect infiltration attacks have to be explored.
